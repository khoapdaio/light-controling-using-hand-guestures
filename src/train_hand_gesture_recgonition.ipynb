# %%
# Tạo folder data để các bạn upload file 3 file data được tạo ra ở step 0 vào folder data
# Các bạn upload file hand_gesture.yaml ngoài folder data
# !mkdir ..\data
# Out:
# A subdirectory or file ..\data already exists.

# %%
# Nếu đã chạy thành công step 0 thì các bạn không chạy cell này và chỉ upload 3 file data của các bạn vào thư mục data
# Và upload file hand_gesture.yaml bên ngoài thư mục data
# Nếu không chạy được ở step 0 thì các bạn run cell này để download data
# !gdown  1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu -O ..\data
# !gdown  15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf -O ..\data
# !gdown  1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq -O ..\data
# Download file hand_gesture.yam
# !gdown  1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw ..\
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1gzWOtABiVmJ38usCSDe5F9gR2tECt3zu
# To: O:\Git\light-controling-using-hand-guestures\data
#
#   0%|          | 0.00/369k [00:00<?, ?B/s]
# 100%|##########| 369k/369k [00:00<00:00, 915kB/s]
# 100%|##########| 369k/369k [00:00<00:00, 913kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=15lwipssmC_K82ukRfb0uVCiDH1TZ3QCf
# To: O:\Git\light-controling-using-hand-guestures\data
#
#   0%|          | 0.00/1.28M [00:00<?, ?B/s]
#  41%|####      | 524k/1.28M [00:04<00:06, 117kB/s]
#  82%|########1 | 1.05M/1.28M [00:04<00:00, 254kB/s]
# 100%|##########| 1.28M/1.28M [00:04<00:00, 334kB/s]
# 100%|##########| 1.28M/1.28M [00:04<00:00, 258kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1nIo1_wBmkovz-u_BCsV5c1Kbz6ZqoKwq
# To: O:\Git\light-controling-using-hand-guestures\data
#
#   0%|          | 0.00/320k [00:00<?, ?B/s]
# 100%|##########| 320k/320k [00:00<00:00, 843kB/s]
# 100%|##########| 320k/320k [00:00<00:00, 841kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZteHYSgbuZu_GcUJHW8ZzoZv1DE8-oLw
# To: O:\Git\light-controling-using-hand-guestures\src\hand_gesture.yaml
#
#   0%|          | 0.00/120 [00:00<?, ?B/s]
# 100%|##########| 120/120 [00:00<?, ?B/s]

# %%
# !pip install mediapipe==0.10.18
# Out:
# Collecting mediapipe==0.10.18
#   Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (24.3.25)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.4.33)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (3.8.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (4.10.0.84)
# Collecting protobuf<5,>=4.25.3 (from mediapipe==0.10.18)
#   Downloading protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe==0.10.18)
#   Downloading sounddevice-0.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from mediapipe==0.10.18) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.10/dist-packages (from sounddevice>=0.4.4->mediapipe==0.10.18) (1.17.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (0.4.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /usr/local/lib/python3.10/dist-packages (from jax->mediapipe==0.10.18) (1.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mediapipe==0.10.18) (2.8.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.18) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe==0.10.18) (1.16.0)
# Downloading mediapipe-0.10.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 35.0 MB/s eta 0:00:00
# Downloading protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 16.0 MB/s eta 0:00:00
# Downloading sounddevice-0.5.1-py3-none-any.whl (32 kB)
# Installing collected packages: protobuf, sounddevice, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.5 which is incompatible.
# Successfully installed mediapipe-0.10.18 protobuf-4.25.5 sounddevice-0.5.1

# %%
# !pip install torchmetrics
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: numpy>1.20.0 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torchmetrics) (1.26.4)
# Requirement already satisfied: packaging>17.1 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torchmetrics) (24.1)
# Requirement already satisfied: torch>=2.0.0 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torchmetrics) (2.5.0)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: setuptools in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (75.1.0)
# Requirement already satisfied: typing-extensions in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.11.0)
# Requirement already satisfied: filelock in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torch>=2.0.0->torchmetrics) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\khoaddow\anaconda3\envs\gesture_env\lib\site-packages (from jinja2->torch>=2.0.0->torchmetrics) (2.1.3)
# Downloading torchmetrics-1.6.0-py3-none-any.whl (926 kB)
#    ---------------------------------------- 0.0/926.4 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/926.4 kB ? eta -:--:--
#    --------------------------------- ------ 786.4/926.4 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 926.4/926.4 kB 2.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.11.9 torchmetrics-1.6.0

# %%
import os
import cv2
import yaml
import torch
import numpy as np
import pandas as pd
from torch import nn
import mediapipe as mp
from torch import optim
from datetime import datetime
from torchmetrics import Accuracy
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
def label_dict_from_config_file(relative_path):
	with open(relative_path, "r") as f:
		label_tag = yaml.full_load(f)["gestures"]
	return label_tag

# %%
class NeuralNetwork(nn.Module):
	def __init__(self):
		super(NeuralNetwork, self).__init__()
		self.flatten = nn.Flatten()
		list_label = label_dict_from_config_file("../hand_gesture.yaml")
		num_classes = len(list_label)
		self.linear_relu_stack = nn.Sequential(
			# Hidden layer 1
			nn.Linear(63, 128),
			nn.ReLU(),
			nn.BatchNorm1d(128),

			# Hidden layer 2
			nn.Linear(128, 128),
			nn.ReLU(),
			nn.Dropout(p = 0.4),

			# Hidden layer 3
			nn.Linear(128, 128),
			nn.ReLU(),
			nn.Dropout(p = 0.4),

			# Hidden layer 4
			nn.Linear(128, 128),
			nn.ReLU(),
			nn.Dropout(p = 0.6),

			# Output layer
			nn.Linear(128, num_classes)
		)

	def forward(self, x):
		# Flatten the input
		x = self.flatten(x)
		# Pass through the linear_relu_stack
		logits = self.linear_relu_stack(x)
		# Return logits
		return logits

	def predict(self, x, threshold = 0.8):
		logits = self(x)
		softmax_prob = nn.Softmax(dim = 1)(logits)
		chosen_ind = torch.argmax(softmax_prob, dim = 1)
		return torch.where(softmax_prob[0, chosen_ind] > threshold, chosen_ind, -1)

	def predict_with_known_class(self, x):
		logits = self(x)
		softmax_prob = nn.Softmax(dim = 1)(logits)
		return torch.argmax(softmax_prob, dim = 1)

	def score(self, logits):
		return -torch.amax(logits, dim = 1)

# %%
class HandLandmarksDetector():
	def __init__(self) -> None:
		self.mp_drawing = mp.solutions.drawing_utils
		self.mp_drawing_styles = mp.solutions.drawing_styles
		self.mp_hands = mp.solutions.hands
		self.detector = self.mp_hands.Hands(False, max_num_hands = 1, min_detection_confidence = 0.5)

	def detectHand(self, frame):
		hands = []
		frame = cv2.flip(frame, 1)
		annotated_image = frame.copy()
		results = self.detector.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
		if results.multi_hand_landmarks is not None:
			for hand_landmarks in results.multi_hand_landmarks:
				hand = []
				self.mp_drawing.draw_landmarks(
					annotated_image,
					hand_landmarks,
					self.mp_hands.HAND_CONNECTIONS,
					self.mp_drawing_styles.get_default_hand_landmarks_style(),
					self.mp_drawing_styles.get_default_hand_connections_style())
				for landmark in hand_landmarks.landmark:
					x, y, z = landmark.x, landmark.y, landmark.z
					hand.extend([x, y, z])
			hands.append(hand)
		return hands, annotated_image

# %%
class CustomImageDataset(Dataset):
	def __init__(self, data_file):
		self.data = pd.read_csv(data_file)
		self.labels = torch.from_numpy(self.data.iloc[:, 0].to_numpy())

	def __len__(self):
		return len(self.data)

	def __getitem__(self, idx):
		one_hot_label = self.labels[idx]
		torch_data = torch.from_numpy(self.data.iloc[idx, 1:].to_numpy(dtype = np.float32))
		return torch_data, one_hot_label

# %%
class EarlyStopper:
	def __init__(self, patience = 1, min_delta = 0):
		self.patience = patience
		self.min_delta = min_delta
		self.counter = 0
		self.watched_metrics = np.inf

	def early_stop(self, current_value):
		if current_value < self.watched_metrics:
			self.watched_metrics = current_value
			self.counter = 0
		elif current_value > (self.watched_metrics + self.min_delta):
			self.counter += 1
			if self.counter >= self.patience:
				return True
		return False

# %%
def train(trainloader, val_loader, model, loss_function, early_stopper, optimizer):
	# add auroc score
	best_vloss = 1_000_000
	timestamp = datetime.now().strftime('%d-%m %H:%M')
	for epoch in range(300):
		#training step
		model.train(True)
		running_loss = 0.0
		acc_train = Accuracy(num_classes = len(LIST_LABEL), task = 'MULTICLASS')
		for batch_number, data in enumerate(trainloader):
			inputs, labels = data

			################## Your Code Here ################## Q9
			''' Hoàn thành code để thực hiện reset gradients và dự đoán class cử
            chỉ của inputs
            '''
			optimizer.zero_grad()
			preds = model(inputs)
			####################################################

			################## Your Code Here ################## Q10
			''' Hoàn thành code để thực hiện tính loss dưa vào kết quả dự đoán
            và labels, sau đó thực hiện backwward và update parameters thông qua
            optimizer
            '''
			loss = loss_function(preds, labels)
			loss.backward()
			optimizer.step()

			####################################################

			acc_train.update(model.predict_with_known_class(inputs), labels)
			running_loss += loss.item()
		avg_loss = running_loss / len(trainloader)
		# validating step
		model.train(False)
		running_vloss = 0.0
		acc_val = Accuracy(num_classes = len(LIST_LABEL), task = 'MULTICLASS')
		for i, vdata in enumerate(val_loader):
			vinputs, vlabels = vdata
			preds = model(vinputs)
			vloss = loss_function(preds, vlabels)
			running_vloss += vloss.item()
			acc_val.update(model.predict_with_known_class(vinputs), vlabels)

		# Log the running loss averaged per batch
		# for both training and validation
		print(f"Epoch {epoch}: ")
		print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
		avg_vloss = running_vloss / len(val_loader)
		print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
		print('Training vs. Validation Loss',
		      {'Training': avg_loss, 'Validation': avg_vloss},
		      epoch + 1)
		print('Training vs. Validation accuracy',
		      {'Training': acc_train.compute().item()
			      , 'Validation': acc_val.compute().item()},
		      epoch + 1)

		# Track best performance, and save the model's state
		if avg_vloss < best_vloss:
			best_vloss = avg_vloss
			best_model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_best'
			torch.save(model.state_dict(), best_model_path)

		if early_stopper.early_stop(avg_vloss):
			################## Your Code Here ################## Q5
			''' Hoàn thành đoạn code bên dướ để  print ra epoch hiện tại và
            minimum watched metric và thoát loop
            '''
			print(f" stopping at epoch {epoch} , minimum : {early_stopper.watched_metrics}")
			break
	####################################################

	model_path = f'./{save_path}/model_{timestamp}_{model.__class__.__name__}_last'
	torch.save(model.state_dict(), model_path)

	print(acc_val.compute())
	return model, best_model_path

# %%
DATA_FOLDER_PATH = "../data2/"
LIST_LABEL = label_dict_from_config_file("../hand_gesture.yaml")
train_path = os.path.join(DATA_FOLDER_PATH, "landmark_train.csv")
val_path = os.path.join(DATA_FOLDER_PATH, "landmark_val.csv")
save_path = '../models'
os.makedirs(save_path, exist_ok = True)

trainset = CustomImageDataset(train_path)
################## Your Code Here ################## Q3
'''Hoàn thành code để thực hiện khởi tạo DataLoader cho trainset với
batch_size 40 và cho phép xáo trộn
'''
trainloader = DataLoader(trainset, batch_size = 40, shuffle = True)
####################################################

valset = CustomImageDataset(os.path.join(val_path))
val_loader = torch.utils.data.DataLoader(valset, batch_size = 50, shuffle = False)

################## Your Code Here ################## Q8
'''Hoàn thành code để thực hiện khởi tạo NeuralNetwork model đã xây dựng ở trên,
khởi tạo hàm loss sử dụng CrossEntropyLoss và khởi tạo early stopper với patience
là 30 và min_delta là 0.01
'''
model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience = 30, min_delta = 0.01)
####################################################

################## Your Code Here ################## Q4
'''Hoàn thành code để thực hiện cấu hình Adam optimizer cho các tham số của
model với tốc độ học là 0.0001
'''
optimizer = optim.Adam(model.parameters(), lr = 0.0001)
####################################################


model, best_model_path = train(trainloader, val_loader, model, loss_function, early_stopper, optimizer)
# Out:
# Epoch 0:
# Accuracy train:0.1461988240480423, val:0.1696428507566452
# LOSS train 1.615868541929457 valid 1.6287397146224976
# Training vs. Validation Loss {'Training': 1.615868541929457, 'Validation': 1.6287397146224976} 1
# Training vs. Validation accuracy {'Training': 0.1461988240480423, 'Validation': 0.1696428507566452} 1
# Epoch 1:
# Accuracy train:0.2426900565624237, val:0.1696428507566452
# LOSS train 1.5930569569269817 valid 1.6262285709381104
# Training vs. Validation Loss {'Training': 1.5930569569269817, 'Validation': 1.6262285709381104} 2
# Training vs. Validation accuracy {'Training': 0.2426900565624237, 'Validation': 0.1696428507566452} 2
# Epoch 2:
# Accuracy train:0.2923976480960846, val:0.4464285671710968
# LOSS train 1.5791174173355103 valid 1.615882118542989
# Training vs. Validation Loss {'Training': 1.5791174173355103, 'Validation': 1.615882118542989} 3
# Training vs. Validation accuracy {'Training': 0.2923976480960846, 'Validation': 0.4464285671710968} 3
# Epoch 3:
# Accuracy train:0.35672515630722046, val:0.4464285671710968
# LOSS train 1.5477679173151653 valid 1.5946811040242512
# Training vs. Validation Loss {'Training': 1.5477679173151653, 'Validation': 1.5946811040242512} 4
# Training vs. Validation accuracy {'Training': 0.35672515630722046, 'Validation': 0.4464285671710968} 4
# Epoch 4:
# Accuracy train:0.48830410838127136, val:0.6785714030265808
# LOSS train 1.5220087634192572 valid 1.5652877887090046
# Training vs. Validation Loss {'Training': 1.5220087634192572, 'Validation': 1.5652877887090046} 5
# Training vs. Validation accuracy {'Training': 0.48830410838127136, 'Validation': 0.6785714030265808} 5
# Epoch 5:
# Accuracy train:0.567251443862915, val:0.6785714030265808
# LOSS train 1.4989446666505601 valid 1.5376620690027873
# Training vs. Validation Loss {'Training': 1.4989446666505601, 'Validation': 1.5376620690027873} 6
# Training vs. Validation accuracy {'Training': 0.567251443862915, 'Validation': 0.6785714030265808} 6
# Epoch 6:
# Accuracy train:0.7251461744308472, val:0.6785714030265808
# LOSS train 1.4599214527342055 valid 1.507660706837972
# Training vs. Validation Loss {'Training': 1.4599214527342055, 'Validation': 1.507660706837972} 7
# Training vs. Validation accuracy {'Training': 0.7251461744308472, 'Validation': 0.6785714030265808} 7
# Epoch 7:
# Accuracy train:0.7339181303977966, val:0.6785714030265808
# LOSS train 1.4060430924097698 valid 1.474328915278117
# Training vs. Validation Loss {'Training': 1.4060430924097698, 'Validation': 1.474328915278117} 8
# Training vs. Validation accuracy {'Training': 0.7339181303977966, 'Validation': 0.6785714030265808} 8
# Epoch 8:
# Accuracy train:0.7748538255691528, val:0.6785714030265808
# LOSS train 1.360780742433336 valid 1.4329646825790405
# Training vs. Validation Loss {'Training': 1.360780742433336, 'Validation': 1.4329646825790405} 9
# Training vs. Validation accuracy {'Training': 0.7748538255691528, 'Validation': 0.6785714030265808} 9
# Epoch 9:
# Accuracy train:0.792397677898407, val:0.6785714030265808
# LOSS train 1.290435102250841 valid 1.390765865643819
# Training vs. Validation Loss {'Training': 1.290435102250841, 'Validation': 1.390765865643819} 10
# Training vs. Validation accuracy {'Training': 0.792397677898407, 'Validation': 0.6785714030265808} 10
# Epoch 10:
# Accuracy train:0.8187134265899658, val:0.6785714030265808
# LOSS train 1.1945767137739394 valid 1.3307708104451497
# Training vs. Validation Loss {'Training': 1.1945767137739394, 'Validation': 1.3307708104451497} 11
# Training vs. Validation accuracy {'Training': 0.8187134265899658, 'Validation': 0.6785714030265808} 11
# Epoch 11:
# Accuracy train:0.8040935397148132, val:0.6785714030265808
# LOSS train 1.103554778628879 valid 1.2715503573417664
# Training vs. Validation Loss {'Training': 1.103554778628879, 'Validation': 1.2715503573417664} 12
# Training vs. Validation accuracy {'Training': 0.8040935397148132, 'Validation': 0.6785714030265808} 12
# Epoch 12:
# Accuracy train:0.8099415302276611, val:0.5089285969734192
# LOSS train 0.995686928431193 valid 1.214603861172994
# Training vs. Validation Loss {'Training': 0.995686928431193, 'Validation': 1.214603861172994} 13
# Training vs. Validation accuracy {'Training': 0.8099415302276611, 'Validation': 0.5089285969734192} 13
# Epoch 13:
# Accuracy train:0.8011695742607117, val:0.5089285969734192
# LOSS train 0.8781861994001601 valid 1.1794294913609822
# Training vs. Validation Loss {'Training': 0.8781861994001601, 'Validation': 1.1794294913609822} 14
# Training vs. Validation accuracy {'Training': 0.8011695742607117, 'Validation': 0.5089285969734192} 14
# Epoch 14:
# Accuracy train:0.8157894611358643, val:0.5089285969734192
# LOSS train 0.7486994134055244 valid 1.1264458000659943
# Training vs. Validation Loss {'Training': 0.7486994134055244, 'Validation': 1.1264458000659943} 15
# Training vs. Validation accuracy {'Training': 0.8157894611358643, 'Validation': 0.5089285969734192} 15
# Epoch 15:
# Accuracy train:0.8070175647735596, val:0.5089285969734192
# LOSS train 0.6383012533187866 valid 1.091293841600418
# Training vs. Validation Loss {'Training': 0.6383012533187866, 'Validation': 1.091293841600418} 16
# Training vs. Validation accuracy {'Training': 0.8070175647735596, 'Validation': 0.5089285969734192} 16
# Epoch 16:
# Accuracy train:0.8070175647735596, val:0.5089285969734192
# LOSS train 0.5961128075917562 valid 1.1143373052279155
# Training vs. Validation Loss {'Training': 0.5961128075917562, 'Validation': 1.1143373052279155} 17
# Training vs. Validation accuracy {'Training': 0.8070175647735596, 'Validation': 0.5089285969734192} 17
# Epoch 17:
# Accuracy train:0.7894737124443054, val:0.5089285969734192
# LOSS train 0.5398534701930152 valid 1.0647701347867649
# Training vs. Validation Loss {'Training': 0.5398534701930152, 'Validation': 1.0647701347867649} 18
# Training vs. Validation accuracy {'Training': 0.7894737124443054, 'Validation': 0.5089285969734192} 18
# Epoch 18:
# Accuracy train:0.8245614171028137, val:0.5089285969734192
# LOSS train 0.47107890248298645 valid 1.0837853290140629
# Training vs. Validation Loss {'Training': 0.47107890248298645, 'Validation': 1.0837853290140629} 19
# Training vs. Validation accuracy {'Training': 0.8245614171028137, 'Validation': 0.5089285969734192} 19
# Epoch 19:
# Accuracy train:0.8187134265899658, val:0.5089285969734192
# LOSS train 0.4676221079296536 valid 1.111111259708802
# Training vs. Validation Loss {'Training': 0.4676221079296536, 'Validation': 1.111111259708802} 20
# Training vs. Validation accuracy {'Training': 0.8187134265899658, 'Validation': 0.5089285969734192} 20
# Epoch 20:
# Accuracy train:0.8362573385238647, val:0.5089285969734192
# LOSS train 0.4561098880238003 valid 1.0328272885332506
# Training vs. Validation Loss {'Training': 0.4561098880238003, 'Validation': 1.0328272885332506} 21
# Training vs. Validation accuracy {'Training': 0.8362573385238647, 'Validation': 0.5089285969734192} 21
# Epoch 21:
# Accuracy train:0.8362573385238647, val:0.6785714030265808
# LOSS train 0.40066893729898667 valid 0.9952831640839577
# Training vs. Validation Loss {'Training': 0.40066893729898667, 'Validation': 0.9952831640839577} 22
# Training vs. Validation accuracy {'Training': 0.8362573385238647, 'Validation': 0.6785714030265808} 22
# Epoch 22:
# Accuracy train:0.8391813039779663, val:0.6785714030265808
# LOSS train 0.4017698930369483 valid 0.9952995994438728
# Training vs. Validation Loss {'Training': 0.4017698930369483, 'Validation': 0.9952995994438728} 23
# Training vs. Validation accuracy {'Training': 0.8391813039779663, 'Validation': 0.6785714030265808} 23
# Epoch 23:
# Accuracy train:0.859649121761322, val:0.6785714030265808
# LOSS train 0.3701329198148515 valid 0.9915009951218963
# Training vs. Validation Loss {'Training': 0.3701329198148515, 'Validation': 0.9915009951218963} 24
# Training vs. Validation accuracy {'Training': 0.859649121761322, 'Validation': 0.6785714030265808} 24
# Epoch 24:
# Accuracy train:0.859649121761322, val:0.6785714030265808
# LOSS train 0.3691699273056454 valid 0.9626752935970823
# Training vs. Validation Loss {'Training': 0.3691699273056454, 'Validation': 0.9626752935970823} 25
# Training vs. Validation accuracy {'Training': 0.859649121761322, 'Validation': 0.6785714030265808} 25
# Epoch 25:
# Accuracy train:0.8684210777282715, val:0.6785714030265808
# LOSS train 0.3418901049428516 valid 0.967782363605996
# Training vs. Validation Loss {'Training': 0.3418901049428516, 'Validation': 0.967782363605996} 26
# Training vs. Validation accuracy {'Training': 0.8684210777282715, 'Validation': 0.6785714030265808} 26
# Epoch 26:
# Accuracy train:0.871345043182373, val:0.6785714030265808
# LOSS train 0.32617608706156415 valid 0.9666973023364941
# Training vs. Validation Loss {'Training': 0.32617608706156415, 'Validation': 0.9666973023364941} 27
# Training vs. Validation accuracy {'Training': 0.871345043182373, 'Validation': 0.6785714030265808} 27
# Epoch 27:
# Accuracy train:0.9122806787490845, val:0.6785714030265808
# LOSS train 0.3212718615929286 valid 0.8756769344521066
# Training vs. Validation Loss {'Training': 0.3212718615929286, 'Validation': 0.8756769344521066} 28
# Training vs. Validation accuracy {'Training': 0.9122806787490845, 'Validation': 0.6785714030265808} 28
# Epoch 28:
# Accuracy train:0.8918128609657288, val:0.6785714030265808
# LOSS train 0.304894099632899 valid 0.8693915931507945
# Training vs. Validation Loss {'Training': 0.304894099632899, 'Validation': 0.8693915931507945} 29
# Training vs. Validation accuracy {'Training': 0.8918128609657288, 'Validation': 0.6785714030265808} 29
# Epoch 29:
# Accuracy train:0.8918128609657288, val:0.7321428656578064
# LOSS train 0.29345234400696224 valid 0.8158667917208126
# Training vs. Validation Loss {'Training': 0.29345234400696224, 'Validation': 0.8158667917208126} 30
# Training vs. Validation accuracy {'Training': 0.8918128609657288, 'Validation': 0.7321428656578064} 30
# Epoch 30:
# Accuracy train:0.9239766001701355, val:0.8571428656578064
# LOSS train 0.27835864822069806 valid 0.7876831169705838
# Training vs. Validation Loss {'Training': 0.27835864822069806, 'Validation': 0.7876831169705838} 31
# Training vs. Validation accuracy {'Training': 0.9239766001701355, 'Validation': 0.8571428656578064} 31
# Epoch 31:
# Accuracy train:0.9210526347160339, val:0.8571428656578064
# LOSS train 0.28497302697764504 valid 0.7897934434004128
# Training vs. Validation Loss {'Training': 0.28497302697764504, 'Validation': 0.7897934434004128} 32
# Training vs. Validation accuracy {'Training': 0.9210526347160339, 'Validation': 0.8571428656578064} 32
# Epoch 32:
# Accuracy train:0.9415204524993896, val:0.875
# LOSS train 0.2630986322959264 valid 0.7739644498409083
# Training vs. Validation Loss {'Training': 0.2630986322959264, 'Validation': 0.7739644498409083} 33
# Training vs. Validation accuracy {'Training': 0.9415204524993896, 'Validation': 0.875} 33
# Epoch 33:
# Accuracy train:0.9561403393745422, val:0.8839285969734192
# LOSS train 0.2400390240881178 valid 0.738252735696733
# Training vs. Validation Loss {'Training': 0.2400390240881178, 'Validation': 0.738252735696733} 34
# Training vs. Validation accuracy {'Training': 0.9561403393745422, 'Validation': 0.8839285969734192} 34
# Epoch 34:
# Accuracy train:0.9619883298873901, val:0.8839285969734192
# LOSS train 0.22156662742296854 valid 0.6905505439111342
# Training vs. Validation Loss {'Training': 0.22156662742296854, 'Validation': 0.6905505439111342} 35
# Training vs. Validation accuracy {'Training': 0.9619883298873901, 'Validation': 0.8839285969734192} 35
# Epoch 35:
# Accuracy train:0.9707602262496948, val:0.8839285969734192
# LOSS train 0.210966890056928 valid 0.6684803954946498
# Training vs. Validation Loss {'Training': 0.210966890056928, 'Validation': 0.6684803954946498} 36
# Training vs. Validation accuracy {'Training': 0.9707602262496948, 'Validation': 0.8839285969734192} 36
# Epoch 36:
# Accuracy train:0.9678362607955933, val:0.8839285969734192
# LOSS train 0.18170230918460423 valid 0.6791855624566475
# Training vs. Validation Loss {'Training': 0.18170230918460423, 'Validation': 0.6791855624566475} 37
# Training vs. Validation accuracy {'Training': 0.9678362607955933, 'Validation': 0.8839285969734192} 37
# Epoch 37:
# Accuracy train:0.9736841917037964, val:0.8839285969734192
# LOSS train 0.16704343176550335 valid 0.6069240012827019
# Training vs. Validation Loss {'Training': 0.16704343176550335, 'Validation': 0.6069240012827019} 38
# Training vs. Validation accuracy {'Training': 0.9736841917037964, 'Validation': 0.8839285969734192} 38
# Epoch 38:
# Accuracy train:0.9707602262496948, val:0.8839285969734192
# LOSS train 0.15339920338657168 valid 0.5641282310243696
# Training vs. Validation Loss {'Training': 0.15339920338657168, 'Validation': 0.5641282310243696} 39
# Training vs. Validation accuracy {'Training': 0.9707602262496948, 'Validation': 0.8839285969734192} 39
# Epoch 39:
# Accuracy train:0.9707602262496948, val:0.8839285969734192
# LOSS train 0.12708331478966606 valid 0.5134436463316282
# Training vs. Validation Loss {'Training': 0.12708331478966606, 'Validation': 0.5134436463316282} 40
# Training vs. Validation accuracy {'Training': 0.9707602262496948, 'Validation': 0.8839285969734192} 40
# Epoch 40:
# Accuracy train:0.9766082167625427, val:0.8839285969734192
# LOSS train 0.12872207288940749 valid 0.5105496025644243
# Training vs. Validation Loss {'Training': 0.12872207288940749, 'Validation': 0.5105496025644243} 41
# Training vs. Validation accuracy {'Training': 0.9766082167625427, 'Validation': 0.8839285969734192} 41
# Epoch 41:
# Accuracy train:0.9795321822166443, val:0.8839285969734192
# LOSS train 0.1082850984401173 valid 0.5010982463136315
# Training vs. Validation Loss {'Training': 0.1082850984401173, 'Validation': 0.5010982463136315} 42
# Training vs. Validation accuracy {'Training': 0.9795321822166443, 'Validation': 0.8839285969734192} 42
# Epoch 42:
# Accuracy train:0.9766082167625427, val:0.8839285969734192
# LOSS train 0.0971466586407688 valid 0.4601251124404371
# Training vs. Validation Loss {'Training': 0.0971466586407688, 'Validation': 0.4601251124404371} 43
# Training vs. Validation accuracy {'Training': 0.9766082167625427, 'Validation': 0.8839285969734192} 43
# Epoch 43:
# Accuracy train:0.9736841917037964, val:1.0
# LOSS train 0.09876109121574296 valid 0.411091710984086
# Training vs. Validation Loss {'Training': 0.09876109121574296, 'Validation': 0.411091710984086} 44
# Training vs. Validation accuracy {'Training': 0.9736841917037964, 'Validation': 1.0} 44
# Epoch 44:
# Accuracy train:0.9795321822166443, val:1.0
# LOSS train 0.09131119814183977 valid 0.394697146761852
# Training vs. Validation Loss {'Training': 0.09131119814183977, 'Validation': 0.394697146761852} 45
# Training vs. Validation accuracy {'Training': 0.9795321822166443, 'Validation': 1.0} 45
# Epoch 45:
# Accuracy train:0.9795321822166443, val:1.0
# LOSS train 0.07734213148554166 valid 0.39383037941297516
# Training vs. Validation Loss {'Training': 0.07734213148554166, 'Validation': 0.39383037941297516} 46
# Training vs. Validation accuracy {'Training': 0.9795321822166443, 'Validation': 1.0} 46
# Epoch 46:
# Accuracy train:0.988304078578949, val:1.0
# LOSS train 0.08321521700256401 valid 0.3784630685695447
# Training vs. Validation Loss {'Training': 0.08321521700256401, 'Validation': 0.3784630685695447} 47
# Training vs. Validation accuracy {'Training': 0.988304078578949, 'Validation': 1.0} 47
# Epoch 47:
# Accuracy train:0.9912280440330505, val:1.0
# LOSS train 0.07529648434784678 valid 0.37655229536661255
# Training vs. Validation Loss {'Training': 0.07529648434784678, 'Validation': 0.37655229536661255} 48
# Training vs. Validation accuracy {'Training': 0.9912280440330505, 'Validation': 1.0} 48
# Epoch 48:
# Accuracy train:0.9912280440330505, val:1.0
# LOSS train 0.0620430852803919 valid 0.3330349252792075
# Training vs. Validation Loss {'Training': 0.0620430852803919, 'Validation': 0.3330349252792075} 49
# Training vs. Validation accuracy {'Training': 0.9912280440330505, 'Validation': 1.0} 49
# Epoch 49:
# Accuracy train:0.988304078578949, val:1.0
# LOSS train 0.05621711816638708 valid 0.29051600573196384
# Training vs. Validation Loss {'Training': 0.05621711816638708, 'Validation': 0.29051600573196384} 50
# Training vs. Validation accuracy {'Training': 0.988304078578949, 'Validation': 1.0} 50
# Epoch 50:
# Accuracy train:1.0, val:1.0
# LOSS train 0.053960280751602516 valid 0.27941472869133577
# Training vs. Validation Loss {'Training': 0.053960280751602516, 'Validation': 0.27941472869133577} 51
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 51
# Epoch 51:
# Accuracy train:0.9912280440330505, val:1.0
# LOSS train 0.043232503812760115 valid 0.24244220807061842
# Training vs. Validation Loss {'Training': 0.043232503812760115, 'Validation': 0.24244220807061842} 52
# Training vs. Validation accuracy {'Training': 0.9912280440330505, 'Validation': 1.0} 52
# Epoch 52:
# Accuracy train:0.9941520690917969, val:1.0
# LOSS train 0.04622702217764325 valid 0.23479259147037132
# Training vs. Validation Loss {'Training': 0.04622702217764325, 'Validation': 0.23479259147037132} 53
# Training vs. Validation accuracy {'Training': 0.9941520690917969, 'Validation': 1.0} 53
# Epoch 53:
# Accuracy train:0.9941520690917969, val:1.0
# LOSS train 0.04122960019028849 valid 0.22882139340314703
# Training vs. Validation Loss {'Training': 0.04122960019028849, 'Validation': 0.22882139340314703} 54
# Training vs. Validation accuracy {'Training': 0.9941520690917969, 'Validation': 1.0} 54
# Epoch 54:
# Accuracy train:0.9941520690917969, val:1.0
# LOSS train 0.04758296922470132 valid 0.20008952068261956
# Training vs. Validation Loss {'Training': 0.04758296922470132, 'Validation': 0.20008952068261956} 55
# Training vs. Validation accuracy {'Training': 0.9941520690917969, 'Validation': 1.0} 55
# Epoch 55:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.040444946847856045 valid 0.17771746951621026
# Training vs. Validation Loss {'Training': 0.040444946847856045, 'Validation': 0.17771746951621026} 56
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 56
# Epoch 56:
# Accuracy train:1.0, val:1.0
# LOSS train 0.03848392909599675 valid 0.1242898993465739
# Training vs. Validation Loss {'Training': 0.03848392909599675, 'Validation': 0.1242898993465739} 57
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 57
# Epoch 57:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.02764927399241262 valid 0.1315200355796454
# Training vs. Validation Loss {'Training': 0.02764927399241262, 'Validation': 0.1315200355796454} 58
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 58
# Epoch 58:
# Accuracy train:0.9941520690917969, val:1.0
# LOSS train 0.04014716173211733 valid 0.1158344561214714
# Training vs. Validation Loss {'Training': 0.04014716173211733, 'Validation': 0.1158344561214714} 59
# Training vs. Validation accuracy {'Training': 0.9941520690917969, 'Validation': 1.0} 59
# Epoch 59:
# Accuracy train:1.0, val:1.0
# LOSS train 0.025274846909774676 valid 0.09380188532910931
# Training vs. Validation Loss {'Training': 0.025274846909774676, 'Validation': 0.09380188532910931} 60
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 60
# Epoch 60:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.027479501958522532 valid 0.07899158767152888
# Training vs. Validation Loss {'Training': 0.027479501958522532, 'Validation': 0.07899158767152888} 61
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 61
# Epoch 61:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.027563510462641716 valid 0.058224792999681085
# Training vs. Validation Loss {'Training': 0.027563510462641716, 'Validation': 0.058224792999681085} 62
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 62
# Epoch 62:
# Accuracy train:1.0, val:1.0
# LOSS train 0.027289786893460486 valid 0.07075938820586695
# Training vs. Validation Loss {'Training': 0.027289786893460486, 'Validation': 0.07075938820586695} 63
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 63
# Epoch 63:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.019278653379943635 valid 0.05919553464627825
# Training vs. Validation Loss {'Training': 0.019278653379943635, 'Validation': 0.05919553464627825} 64
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 64
# Epoch 64:
# Accuracy train:1.0, val:1.0
# LOSS train 0.018495219345721934 valid 0.05185180210294978
# Training vs. Validation Loss {'Training': 0.018495219345721934, 'Validation': 0.05185180210294978} 65
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 65
# Epoch 65:
# Accuracy train:1.0, val:1.0
# LOSS train 0.020706074312329292 valid 0.03604693701102709
# Training vs. Validation Loss {'Training': 0.020706074312329292, 'Validation': 0.03604693701102709} 66
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 66
# Epoch 66:
# Accuracy train:1.0, val:1.0
# LOSS train 0.018840770030187234 valid 0.03672891938670849
# Training vs. Validation Loss {'Training': 0.018840770030187234, 'Validation': 0.03672891938670849} 67
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 67
# Epoch 67:
# Accuracy train:1.0, val:1.0
# LOSS train 0.02276991426737772 valid 0.03650261859972185
# Training vs. Validation Loss {'Training': 0.02276991426737772, 'Validation': 0.03650261859972185} 68
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 68
# Epoch 68:
# Accuracy train:1.0, val:1.0
# LOSS train 0.02448949375603762 valid 0.030639298439685565
# Training vs. Validation Loss {'Training': 0.02448949375603762, 'Validation': 0.030639298439685565} 69
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 69
# Epoch 69:
# Accuracy train:1.0, val:1.0
# LOSS train 0.018553125465081796 valid 0.02554539575066883
# Training vs. Validation Loss {'Training': 0.018553125465081796, 'Validation': 0.02554539575066883} 70
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 70
# Epoch 70:
# Accuracy train:1.0, val:1.0
# LOSS train 0.013448886573314667 valid 0.017949252520338632
# Training vs. Validation Loss {'Training': 0.013448886573314667, 'Validation': 0.017949252520338632} 71
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 71
# Epoch 71:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.009469093366836509 valid 0.020058858552753616
# Training vs. Validation Loss {'Training': 0.009469093366836509, 'Validation': 0.020058858552753616} 72
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 72
# Epoch 72:
# Accuracy train:1.0, val:1.0
# LOSS train 0.013762256130576134 valid 0.021167632335467108
# Training vs. Validation Loss {'Training': 0.013762256130576134, 'Validation': 0.021167632335467108} 73
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 73
# Epoch 73:
# Accuracy train:0.9970760345458984, val:1.0
# LOSS train 0.01130495241118802 valid 0.023517575192575652
# Training vs. Validation Loss {'Training': 0.01130495241118802, 'Validation': 0.023517575192575652} 74
# Training vs. Validation accuracy {'Training': 0.9970760345458984, 'Validation': 1.0} 74
# Epoch 74:
# Accuracy train:1.0, val:1.0
# LOSS train 0.009690859329162372 valid 0.017150203163813178
# Training vs. Validation Loss {'Training': 0.009690859329162372, 'Validation': 0.017150203163813178} 75
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 75
# Epoch 75:
# Accuracy train:1.0, val:1.0
# LOSS train 0.010583233890227146 valid 0.010576106930481425
# Training vs. Validation Loss {'Training': 0.010583233890227146, 'Validation': 0.010576106930481425} 76
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 76
# Epoch 76:
# Accuracy train:1.0, val:1.0
# LOSS train 0.012185740258751644 valid 0.01310791110881837
# Training vs. Validation Loss {'Training': 0.012185740258751644, 'Validation': 0.01310791110881837} 77
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 77
# Epoch 77:
# Accuracy train:1.0, val:1.0
# LOSS train 0.010111768807594975 valid 0.011435376459606536
# Training vs. Validation Loss {'Training': 0.010111768807594975, 'Validation': 0.011435376459606536} 78
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 78
# Epoch 78:
# Accuracy train:1.0, val:1.0
# LOSS train 0.014480004811452495 valid 0.00825892691500485
# Training vs. Validation Loss {'Training': 0.014480004811452495, 'Validation': 0.00825892691500485} 79
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 79
# Epoch 79:
# Accuracy train:1.0, val:1.0
# LOSS train 0.013365626697325043 valid 0.013683278078436464
# Training vs. Validation Loss {'Training': 0.013365626697325043, 'Validation': 0.013683278078436464} 80
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0}
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 287
# Epoch 287:
# Accuracy train:1.0, val:1.0
# LOSS train 0.000535211378014032 valid 1.880852526170429e-06
# Training vs. Validation Loss {'Training': 0.000535211378014032, 'Validation': 1.880852526170429e-06} 288
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 288
# Epoch 288:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001176945052268113 valid 1.670780591211951e-06
# Training vs. Validation Loss {'Training': 0.001176945052268113, 'Validation': 1.670780591211951e-06} 289
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 289
# Epoch 289:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003300688153507912 valid 1.0769881768624145e-06
# Training vs. Validation Loss {'Training': 0.0003300688153507912, 'Validation': 1.0769881768624145e-06} 290
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 290
# Epoch 290:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0009524619271259224 valid 2.410270932765949e-06
# Training vs. Validation Loss {'Training': 0.0009524619271259224, 'Validation': 2.410270932765949e-06} 291
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 291
# Epoch 291:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0010417720999006026 valid 2.1616548337988206e-06
# Training vs. Validation Loss {'Training': 0.0010417720999006026, 'Validation': 2.1616548337988206e-06} 292
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 292
# Epoch 292:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0004996272196472597 valid 1.8268111405816967e-06
# Training vs. Validation Loss {'Training': 0.0004996272196472597, 'Validation': 1.8268111405816967e-06} 293
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 293
# Epoch 293:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002800595809983659 valid 1.6132951922524323e-06
# Training vs. Validation Loss {'Training': 0.0002800595809983659, 'Validation': 1.6132951922524323e-06} 294
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 294
# Epoch 294:
# Accuracy train:1.0, val:1.0
# LOSS train 0.001192580167197674 valid 1.910919812312765e-06
# Training vs. Validation Loss {'Training': 0.001192580167197674, 'Validation': 1.910919812312765e-06} 295
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 295
# Epoch 295:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0003622134344267478 valid 3.6913617051936853e-06
# Training vs. Validation Loss {'Training': 0.0003622134344267478, 'Validation': 3.6913617051936853e-06} 296
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 296
# Epoch 296:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0002050109370530764 valid 1.8362154818873933e-06
# Training vs. Validation Loss {'Training': 0.0002050109370530764, 'Validation': 1.8362154818873933e-06} 297
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 297
# Epoch 297:
# Accuracy train:1.0, val:1.0
# LOSS train 0.0013964961035526358 valid 5.941915640998255e-07
# Training vs. Validation Loss {'Training': 0.0013964961035526358, 'Validation': 5.941915640998255e-07} 298
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 298
# Epoch 298:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00035694834756820154 valid 3.9081881837432775e-06
# Training vs. Validation Loss {'Training': 0.00035694834756820154, 'Validation': 3.9081881837432775e-06} 299
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 299
# Epoch 299:
# Accuracy train:1.0, val:1.0
# LOSS train 0.00011696697240242631 valid 4.036932368241726e-06
# Training vs. Validation Loss {'Training': 0.00011696697240242631, 'Validation': 4.036932368241726e-06} 300
# Training vs. Validation accuracy {'Training': 1.0, 'Validation': 1.0} 300
# tensor(1.)

# %%
list_label = label_dict_from_config_file("../hand_gesture.yaml")
DATA_FOLDER_PATH = "../data2/"
testset = CustomImageDataset(os.path.join(DATA_FOLDER_PATH, "landmark_test.csv"))

# Test DataLoader instantiation
################## Your Code Here ################## Q6
''' Hoàn thành code bên dưới để  khởi tạo DataLoader cho testset with batch size
20, không cho phép shuffle
'''
test_loader = DataLoader(testset, batch_size = 20, shuffle = False)
####################################################


network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only = False))

network.eval()
acc_test = Accuracy(num_classes = len(list_label), task = 'MULTICLASS')
for i, test_data in enumerate(test_loader):
	test_input, test_label = test_data
	################## Your Code Here ################## Q7
	'''Hoàn thành code bên dưới để  predict class của cử chỉ và update accuracy
    với kết quả predict và true labels
    '''
	preds = network(test_input)
	acc_test.update(preds, test_label)

####################################################

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:1.0
# ========================================================================
